# %% [markdown]
# <a href="https://colab.research.google.com/github/shumshersubashgautam/Yolo_Classification_Autism/blob/main/Yolov8_autism_optimization_200epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Mar 22 07:22:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 7057, done.
# remote: Counting objects: 100% (612/612), done.
# remote: Compressing objects: 100% (291/291), done.
# remote: Total 7057 (delta 419), reused 469 (delta 320), pack-reused 6445
# Receiving objects: 100% (7057/7057), 4.96 MiB | 8.87 MiB/s, done.
# Resolving deltas: 100% (4847/4847), done.

# %%
cd ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Out:
# /content/ultralytics

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.5/485.5 KB 33.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 23.3 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.4/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/autism.zip /content/ultralytics/

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/content/ultralytics/autism epochs=200 optimizer = Adam lr0 = 0.001 lr0= 0.001 momentum=0.97  imgsz=128
# Out:
# ...
# 100% 5.28M/5.28M [00:01<00:00, 4.32MB/s]
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/content/ultralytics/autism epochs=10 imgsz=128
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls -la /content/ultralytics/runs/classify/train/
# Out:
# total 100
# drwxr-xr-x 3 root root  4096 Mar 22 05:31 .
# drwxr-xr-x 3 root root  4096 Mar 22 05:31 ..
# -rw-r--r-- 1 root root  1395 Mar 22 05:31 args.yaml
# -rw-r--r-- 1 root root 81360 Mar 22 05:33 events.out.tfevents.1679463087.04c4804601c1.3964.0
# -rw-r--r-- 1 root root  2112 Mar 22 05:33 results.csv
# drwxr-xr-x 2 root root  4096 Mar 22 05:31 weights

# %%
# !cat  /content/ultralytics/runs/classify/train/results.csv | head -10
# Out:
#                   epoch,             train/loss,  metrics/accuracy_top1,  metrics/accuracy_top5,               val/loss,                 lr/pg0,                 lr/pg1,                 lr/pg2
#                       0,                0.17309,                0.56429,                      1,                0.60498,               0.070181,              0.0033133,              0.0033133
#                       1,                0.17037,                0.59286,                      1,                0.59097,               0.039523,              0.0059886,              0.0059886
#                       2,                0.16695,                0.65714,                      1,                0.56514,              0.0082047,              0.0080039,              0.0080039
#                       3,                0.16402,                0.54643,                      1,                0.59314,                0.00703,                0.00703,                0.00703
# ...

# %%
# !yolo task=classify mode=val model=/content/ultralytics/runs/classify/train/weights/best.pt data=/content/ultralytics/autism
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#                classes   top1_acc   top5_acc: 100% 18/18 [00:00<00:00, 26.43it/s]
#                    all      0.836          1
# Speed: 0.0ms preprocess, 0.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/ultralytics/runs/classify/val3

# %%
	# !yolo task=classify mode=predict model=/content/ultralytics/runs/classify/train/weights/best.pt source='/content/ultralytics/autism/test/Autistic/'
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/140 /content/ultralytics/autism/test/Autistic/001.jpg: 128x128 Autistic 0.79, Non_Autistic 0.21, 4.9ms
# image 2/140 /content/ultralytics/autism/test/Autistic/002.jpg: 128x128 Autistic 0.80, Non_Autistic 0.20, 4.4ms
# image 3/140 /content/ultralytics/autism/test/Autistic/003.jpg: 128x128 Autistic 0.64, Non_Autistic 0.36, 3.2ms
# image 4/140 /content/ultralytics/autism/test/Autistic/004.jpg: 128x128 Autistic 0.58, Non_Autistic 0.42, 3.7ms
# image 5/140 /content/ultralytics/autism/test/Autistic/005.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.1ms
# image 6/140 /content/ultralytics/autism/test/Autistic/006.jpg: 128x128 Autistic 0.81, Non_Autistic 0.19, 3.1ms
# image 7/140 /content/ultralytics/autism/test/Autistic/007.jpg: 128x128 Autistic 0.69, Non_Autistic 0.31, 3.0ms
# ...

# %%
# !sudo apt-get install python3-pyqt5
# !sudo apt-get install libxcb-xinerama0
# !sudo pip3 install pyqt5
# !sudo pip3 install opencv-python==3.4.10.35
# !sudo pip3 install labelme
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libqt5designer5 libqt5help5 python3-sip
# Suggested packages:
#   python3-pyqt5-dbg
# The following NEW packages will be installed:
#   libqt5designer5 libqt5help5 python3-pyqt5 python3-sip
# 0 upgraded, 4 newly installed, 0 to remove and 23 not upgraded.
# Need to get 5,318 kB of archives.
# After this operation, 23.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libqt5designer5 amd64 5.12.8-0ubuntu1 [2,778 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libqt5help5 amd64 5.12.8-0ubuntu1 [134 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-sip amd64 4.19.21+dfsg-1build1 [87.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pyqt5 amd64 5.14.1+dfsg-3build1 [2,318 kB]
# Fetched 5,318 kB in 3s (2,111 kB/s)
# ...
