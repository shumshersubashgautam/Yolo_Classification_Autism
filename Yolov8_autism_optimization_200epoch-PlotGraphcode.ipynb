# %% [markdown]
# <a href="https://colab.research.google.com/github/shumshersubashgautam/Yolo_Classification_Autism/blob/main/Yolov8_autism_optimization_200epoch-PlotGraphcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Mar 22 07:22:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    27W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 7086, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 7086 (delta 12), reused 20 (delta 7), pack-reused 7057
# Receiving objects: 100% (7086/7086), 4.87 MiB | 22.24 MiB/s, done.
# Resolving deltas: 100% (4917/4917), done.

# %%
cd ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (3.7.1)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (1.22.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (8.4.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 10)) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (1.10.1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (1.13.1+cu116)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 13)) (0.14.1+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (4.65.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 22)) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 23)) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 38)) (5.9.4)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (5.12.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->-r requirements.txt (line 10)) (2022.12.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->-r requirements.txt (line 12)) (4.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 22)) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->-r requirements.txt (line 5)) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->-r requirements.txt (line 5)) (1.16.0)
# Installing collected packages: thop
# Successfully installed thop-0.1.1.post2209072238

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating ultralytics.egg-info
# writing ultralytics.egg-info/PKG-INFO
# writing dependency_links to ultralytics.egg-info/dependency_links.txt
# writing entry points to ultralytics.egg-info/entry_points.txt
# writing requirements to ultralytics.egg-info/requires.txt
# writing top-level names to ultralytics.egg-info/top_level.txt
# writing manifest file 'ultralytics.egg-info/SOURCES.txt'
# reading manifest file 'ultralytics.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '*' found under directory '__pycache__'
# adding license file 'LICENSE'
# writing manifest file 'ultralytics.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/ultralytics
# copying ultralytics/__init__.py -> build/lib/ultralytics
# creating build/lib/ultralytics/tracker
# copying ultralytics/tracker/track.py -> build/lib/ultralytics/tracker
# copying ultralytics/tracker/__init__.py -> build/lib/ultralytics/tracker
# creating build/lib/ultralytics/hub
# copying ultralytics/hub/utils.py -> build/lib/ultralytics/hub
# copying ultralytics/hub/session.py -> build/lib/ultralytics/hub
# copying ultralytics/hub/__init__.py -> build/lib/ultralytics/hub
# copying ultralytics/hub/auth.py -> build/lib/ultralytics/hub
# creating build/lib/ultralytics/yolo
# copying ultralytics/yolo/__init__.py -> build/lib/ultralytics/yolo
# creating build/lib/ultralytics/nn
# copying ultralytics/nn/modules.py -> build/lib/ultralytics/nn
# copying ultralytics/nn/__init__.py -> build/lib/ultralytics/nn
# copying ultralytics/nn/autoshape.py -> build/lib/ultralytics/nn
# copying ultralytics/nn/autobackend.py -> build/lib/ultralytics/nn
# copying ultralytics/nn/tasks.py -> build/lib/ultralytics/nn
# creating build/lib/ultralytics/tracker/trackers
# copying ultralytics/tracker/trackers/bot_sort.py -> build/lib/ultralytics/tracker/trackers
# copying ultralytics/tracker/trackers/__init__.py -> build/lib/ultralytics/tracker/trackers
# copying ultralytics/tracker/trackers/basetrack.py -> build/lib/ultralytics/tracker/trackers
# copying ultralytics/tracker/trackers/byte_tracker.py -> build/lib/ultralytics/tracker/trackers
# creating build/lib/ultralytics/tracker/utils
# copying ultralytics/tracker/utils/matching.py -> build/lib/ultralytics/tracker/utils
# copying ultralytics/tracker/utils/kalman_filter.py -> build/lib/ultralytics/tracker/utils
# copying ultralytics/tracker/utils/__init__.py -> build/lib/ultralytics/tracker/utils
# copying ultralytics/tracker/utils/gmc.py -> build/lib/ultralytics/tracker/utils
# creating build/lib/ultralytics/yolo/cfg
# copying ultralytics/yolo/cfg/__init__.py -> build/lib/ultralytics/yolo/cfg
# creating build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/exporter.py -> build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/validator.py -> build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/__init__.py -> build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/model.py -> build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/trainer.py -> build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/results.py -> build/lib/ultralytics/yolo/engine
# copying ultralytics/yolo/engine/predictor.py -> build/lib/ultralytics/yolo/engine
# creating build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/dataset_wrappers.py -> build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/base.py -> build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/dataset.py -> build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/utils.py -> build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/augment.py -> build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/__init__.py -> build/lib/ultralytics/yolo/data
# copying ultralytics/yolo/data/build.py -> build/lib/ultralytics/yolo/data
# creating build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/plotting.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/files.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/ops.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/loss.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/instance.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/downloads.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/checks.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/benchmarks.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/metrics.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/__init__.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/dist.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/autobatch.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/tal.py -> build/lib/ultralytics/yolo/utils
# copying ultralytics/yolo/utils/torch_utils.py -> build/lib/ultralytics/yolo/utils
# creating build/lib/ultralytics/yolo/v8
# copying ultralytics/yolo/v8/__init__.py -> build/lib/ultralytics/yolo/v8
# creating build/lib/ultralytics/yolo/data/dataloaders
# copying ultralytics/yolo/data/dataloaders/v5loader.py -> build/lib/ultralytics/yolo/data/dataloaders
# copying ultralytics/yolo/data/dataloaders/stream_loaders.py -> build/lib/ultralytics/yolo/data/dataloaders
# copying ultralytics/yolo/data/dataloaders/v5augmentations.py -> build/lib/ultralytics/yolo/data/dataloaders
# copying ultralytics/yolo/data/dataloaders/__init__.py -> build/lib/ultralytics/yolo/data/dataloaders
# creating build/lib/ultralytics/yolo/utils/callbacks
# copying ultralytics/yolo/utils/callbacks/hub.py -> build/lib/ultralytics/yolo/utils/callbacks
# copying ultralytics/yolo/utils/callbacks/comet.py -> build/lib/ultralytics/yolo/utils/callbacks
# copying ultralytics/yolo/utils/callbacks/base.py -> build/lib/ultralytics/yolo/utils/callbacks
# copying ultralytics/yolo/utils/callbacks/clearml.py -> build/lib/ultralytics/yolo/utils/callbacks
# copying ultralytics/yolo/utils/callbacks/tensorboard.py -> build/lib/ultralytics/yolo/utils/callbacks
# copying ultralytics/yolo/utils/callbacks/__init__.py -> build/lib/ultralytics/yolo/utils/callbacks
# creating build/lib/ultralytics/yolo/v8/detect
# copying ultralytics/yolo/v8/detect/val.py -> build/lib/ultralytics/yolo/v8/detect
# copying ultralytics/yolo/v8/detect/train.py -> build/lib/ultralytics/yolo/v8/detect
# copying ultralytics/yolo/v8/detect/__init__.py -> build/lib/ultralytics/yolo/v8/detect
# copying ultralytics/yolo/v8/detect/predict.py -> build/lib/ultralytics/yolo/v8/detect
# creating build/lib/ultralytics/yolo/v8/classify
# copying ultralytics/yolo/v8/classify/val.py -> build/lib/ultralytics/yolo/v8/classify
# copying ultralytics/yolo/v8/classify/train.py -> build/lib/ultralytics/yolo/v8/classify
# copying ultralytics/yolo/v8/classify/__init__.py -> build/lib/ultralytics/yolo/v8/classify
# copying ultralytics/yolo/v8/classify/predict.py -> build/lib/ultralytics/yolo/v8/classify
# creating build/lib/ultralytics/yolo/v8/segment
# copying ultralytics/yolo/v8/segment/val.py -> build/lib/ultralytics/yolo/v8/segment
# copying ultralytics/yolo/v8/segment/train.py -> build/lib/ultralytics/yolo/v8/segment
# copying ultralytics/yolo/v8/segment/__init__.py -> build/lib/ultralytics/yolo/v8/segment
# copying ultralytics/yolo/v8/segment/predict.py -> build/lib/ultralytics/yolo/v8/segment
# /usr/local/lib/python3.9/dist-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'ultralytics.assets' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'ultralytics.assets' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'ultralytics.assets' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'ultralytics.assets' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# /usr/local/lib/python3.9/dist-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'ultralytics.datasets' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'ultralytics.datasets' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'ultralytics.datasets' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'ultralytics.datasets' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# /usr/local/lib/python3.9/dist-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'ultralytics.models.v3' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'ultralytics.models.v3' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'ultralytics.models.v3' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'ultralytics.models.v3' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# /usr/local/lib/python3.9/dist-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'ultralytics.models.v5' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'ultralytics.models.v5' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'ultralytics.models.v5' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'ultralytics.models.v5' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# /usr/local/lib/python3.9/dist-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'ultralytics.models.v8' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'ultralytics.models.v8' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'ultralytics.models.v8' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'ultralytics.models.v8' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# /usr/local/lib/python3.9/dist-packages/setuptools/command/build_py.py:153: SetuptoolsDeprecationWarning:     Installing 'ultralytics.tracker.cfg' as data is deprecated, please list it in `packages`.
#     !!
#
#
#     ############################
#     # Package would be ignored #
#     ############################
#     Python recognizes 'ultralytics.tracker.cfg' as an importable package,
#     but it is not listed in the `packages` configuration of setuptools.
#
#     'ultralytics.tracker.cfg' has been automatically added to the distribution only
#     because it may contain data files, but this behavior is likely to change
#     in future versions of setuptools (and therefore is considered deprecated).
#
#     Please make sure that 'ultralytics.tracker.cfg' is included as a package by using
#     the `packages` configuration field or the proper discovery methods
#     (for example by using `find_namespace_packages(...)`/`find_namespace:`
#     instead of `find_packages(...)`/`find:`).
#
#     You can read more about "package discovery" and "data files" on setuptools
#     documentation page.
#
#
# !!
#
#   check.warn(importable)
# creating build/lib/ultralytics/assets
# copying ultralytics/assets/bus.jpg -> build/lib/ultralytics/assets
# copying ultralytics/assets/zidane.jpg -> build/lib/ultralytics/assets
# creating build/lib/ultralytics/datasets
# copying ultralytics/datasets/Argoverse.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/GlobalWheat2020.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/ImageNet.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/Objects365.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/SKU-110K.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/VOC.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/VisDrone.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/coco.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/coco128-seg.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/coco128.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/coco8-seg.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/coco8.yaml -> build/lib/ultralytics/datasets
# copying ultralytics/datasets/xView.yaml -> build/lib/ultralytics/datasets
# creating build/lib/ultralytics/models
# creating build/lib/ultralytics/models/v3
# copying ultralytics/models/v3/yolov3-spp.yaml -> build/lib/ultralytics/models/v3
# copying ultralytics/models/v3/yolov3-tiny.yaml -> build/lib/ultralytics/models/v3
# copying ultralytics/models/v3/yolov3.yaml -> build/lib/ultralytics/models/v3
# creating build/lib/ultralytics/models/v5
# copying ultralytics/models/v5/yolov5-p6.yaml -> build/lib/ultralytics/models/v5
# copying ultralytics/models/v5/yolov5.yaml -> build/lib/ultralytics/models/v5
# creating build/lib/ultralytics/models/v8
# copying ultralytics/models/v8/yolov8-cls.yaml -> build/lib/ultralytics/models/v8
# copying ultralytics/models/v8/yolov8-p6.yaml -> build/lib/ultralytics/models/v8
# copying ultralytics/models/v8/yolov8-seg.yaml -> build/lib/ultralytics/models/v8
# copying ultralytics/models/v8/yolov8.yaml -> build/lib/ultralytics/models/v8
# creating build/lib/ultralytics/tracker/cfg
# copying ultralytics/tracker/cfg/botsort.yaml -> build/lib/ultralytics/tracker/cfg
# copying ultralytics/tracker/cfg/bytetrack.yaml -> build/lib/ultralytics/tracker/cfg
# copying ultralytics/yolo/cfg/default.yaml -> build/lib/ultralytics/yolo/cfg
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/ultralytics
# creating build/bdist.linux-x86_64/egg/ultralytics/tracker
# creating build/bdist.linux-x86_64/egg/ultralytics/tracker/cfg
# copying build/lib/ultralytics/tracker/cfg/bytetrack.yaml -> build/bdist.linux-x86_64/egg/ultralytics/tracker/cfg
# copying build/lib/ultralytics/tracker/cfg/botsort.yaml -> build/bdist.linux-x86_64/egg/ultralytics/tracker/cfg
# creating build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers
# copying build/lib/ultralytics/tracker/trackers/bot_sort.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers
# copying build/lib/ultralytics/tracker/trackers/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers
# copying build/lib/ultralytics/tracker/trackers/basetrack.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers
# copying build/lib/ultralytics/tracker/trackers/byte_tracker.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers
# copying build/lib/ultralytics/tracker/track.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker
# copying build/lib/ultralytics/tracker/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker
# creating build/bdist.linux-x86_64/egg/ultralytics/tracker/utils
# copying build/lib/ultralytics/tracker/utils/matching.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/utils
# copying build/lib/ultralytics/tracker/utils/kalman_filter.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/utils
# copying build/lib/ultralytics/tracker/utils/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/utils
# copying build/lib/ultralytics/tracker/utils/gmc.py -> build/bdist.linux-x86_64/egg/ultralytics/tracker/utils
# creating build/bdist.linux-x86_64/egg/ultralytics/models
# creating build/bdist.linux-x86_64/egg/ultralytics/models/v5
# copying build/lib/ultralytics/models/v5/yolov5.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v5
# copying build/lib/ultralytics/models/v5/yolov5-p6.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v5
# creating build/bdist.linux-x86_64/egg/ultralytics/models/v3
# copying build/lib/ultralytics/models/v3/yolov3.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v3
# copying build/lib/ultralytics/models/v3/yolov3-spp.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v3
# copying build/lib/ultralytics/models/v3/yolov3-tiny.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v3
# creating build/bdist.linux-x86_64/egg/ultralytics/models/v8
# copying build/lib/ultralytics/models/v8/yolov8-cls.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v8
# copying build/lib/ultralytics/models/v8/yolov8-seg.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v8
# copying build/lib/ultralytics/models/v8/yolov8.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v8
# copying build/lib/ultralytics/models/v8/yolov8-p6.yaml -> build/bdist.linux-x86_64/egg/ultralytics/models/v8
# creating build/bdist.linux-x86_64/egg/ultralytics/hub
# copying build/lib/ultralytics/hub/utils.py -> build/bdist.linux-x86_64/egg/ultralytics/hub
# copying build/lib/ultralytics/hub/session.py -> build/bdist.linux-x86_64/egg/ultralytics/hub
# copying build/lib/ultralytics/hub/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/hub
# copying build/lib/ultralytics/hub/auth.py -> build/bdist.linux-x86_64/egg/ultralytics/hub
# creating build/bdist.linux-x86_64/egg/ultralytics/assets
# copying build/lib/ultralytics/assets/zidane.jpg -> build/bdist.linux-x86_64/egg/ultralytics/assets
# copying build/lib/ultralytics/assets/bus.jpg -> build/bdist.linux-x86_64/egg/ultralytics/assets
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/cfg
# copying build/lib/ultralytics/yolo/cfg/default.yaml -> build/bdist.linux-x86_64/egg/ultralytics/yolo/cfg
# copying build/lib/ultralytics/yolo/cfg/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/cfg
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/exporter.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/validator.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/model.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/trainer.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/results.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# copying build/lib/ultralytics/yolo/engine/predictor.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/engine
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/data/dataset_wrappers.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/data/base.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/data/dataset.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/data/utils.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/data/augment.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/data/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders
# copying build/lib/ultralytics/yolo/data/dataloaders/v5loader.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders
# copying build/lib/ultralytics/yolo/data/dataloaders/stream_loaders.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders
# copying build/lib/ultralytics/yolo/data/dataloaders/v5augmentations.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders
# copying build/lib/ultralytics/yolo/data/dataloaders/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders
# copying build/lib/ultralytics/yolo/data/build.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/data
# copying build/lib/ultralytics/yolo/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/plotting.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/files.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/ops.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/loss.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/callbacks/hub.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/callbacks/comet.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/callbacks/base.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/callbacks/clearml.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/callbacks/tensorboard.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/callbacks/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks
# copying build/lib/ultralytics/yolo/utils/instance.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/downloads.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/checks.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/benchmarks.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/metrics.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/dist.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/autobatch.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/tal.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# copying build/lib/ultralytics/yolo/utils/torch_utils.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/utils
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/v8
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect
# copying build/lib/ultralytics/yolo/v8/detect/val.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect
# copying build/lib/ultralytics/yolo/v8/detect/train.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect
# copying build/lib/ultralytics/yolo/v8/detect/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect
# copying build/lib/ultralytics/yolo/v8/detect/predict.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify
# copying build/lib/ultralytics/yolo/v8/classify/val.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify
# copying build/lib/ultralytics/yolo/v8/classify/train.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify
# copying build/lib/ultralytics/yolo/v8/classify/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify
# copying build/lib/ultralytics/yolo/v8/classify/predict.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify
# copying build/lib/ultralytics/yolo/v8/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8
# creating build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment
# copying build/lib/ultralytics/yolo/v8/segment/val.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment
# copying build/lib/ultralytics/yolo/v8/segment/train.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment
# copying build/lib/ultralytics/yolo/v8/segment/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment
# copying build/lib/ultralytics/yolo/v8/segment/predict.py -> build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment
# creating build/bdist.linux-x86_64/egg/ultralytics/nn
# copying build/lib/ultralytics/nn/modules.py -> build/bdist.linux-x86_64/egg/ultralytics/nn
# copying build/lib/ultralytics/nn/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics/nn
# copying build/lib/ultralytics/nn/autoshape.py -> build/bdist.linux-x86_64/egg/ultralytics/nn
# copying build/lib/ultralytics/nn/autobackend.py -> build/bdist.linux-x86_64/egg/ultralytics/nn
# copying build/lib/ultralytics/nn/tasks.py -> build/bdist.linux-x86_64/egg/ultralytics/nn
# copying build/lib/ultralytics/__init__.py -> build/bdist.linux-x86_64/egg/ultralytics
# creating build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/SKU-110K.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/ImageNet.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/Argoverse.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/Objects365.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/xView.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/coco.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/VisDrone.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/VOC.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/coco128-seg.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/coco8.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/GlobalWheat2020.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/coco8-seg.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# copying build/lib/ultralytics/datasets/coco128.yaml -> build/bdist.linux-x86_64/egg/ultralytics/datasets
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers/bot_sort.py to bot_sort.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers/basetrack.py to basetrack.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/trackers/byte_tracker.py to byte_tracker.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/track.py to track.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/utils/matching.py to matching.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/utils/kalman_filter.py to kalman_filter.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/utils/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/tracker/utils/gmc.py to gmc.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/hub/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/hub/session.py to session.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/hub/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/hub/auth.py to auth.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/cfg/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/exporter.py to exporter.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/validator.py to validator.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/model.py to model.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/trainer.py to trainer.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/results.py to results.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/engine/predictor.py to predictor.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataset_wrappers.py to dataset_wrappers.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/base.py to base.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataset.py to dataset.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/augment.py to augment.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders/v5loader.py to v5loader.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders/stream_loaders.py to stream_loaders.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders/v5augmentations.py to v5augmentations.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/dataloaders/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/data/build.py to build.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/plotting.py to plotting.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/files.py to files.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/ops.py to ops.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/loss.py to loss.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks/hub.py to hub.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks/comet.py to comet.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks/base.py to base.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks/clearml.py to clearml.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks/tensorboard.py to tensorboard.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/callbacks/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/instance.py to instance.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/downloads.py to downloads.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/checks.py to checks.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/benchmarks.py to benchmarks.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/metrics.py to metrics.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/dist.py to dist.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/autobatch.py to autobatch.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/tal.py to tal.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/utils/torch_utils.py to torch_utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect/val.py to val.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect/train.py to train.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/detect/predict.py to predict.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify/val.py to val.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify/train.py to train.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/classify/predict.py to predict.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment/val.py to val.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment/train.py to train.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/yolo/v8/segment/predict.py to predict.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/nn/modules.py to modules.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/nn/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/nn/autoshape.py to autoshape.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/nn/autobackend.py to autobackend.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/nn/tasks.py to tasks.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/ultralytics/__init__.py to __init__.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying ultralytics.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ultralytics.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ultralytics.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ultralytics.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ultralytics.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying ultralytics.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# ultralytics.yolo.utils.__pycache__.__init__.cpython-39: module references __file__
# ultralytics.yolo.utils.__pycache__.checks.cpython-39: module MAY be using inspect.getframeinfo
# ultralytics.yolo.utils.__pycache__.files.cpython-39: module references __file__
# creating dist
# creating 'dist/ultralytics-8.0.55-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing ultralytics-8.0.55-py3.9.egg
# creating /usr/local/lib/python3.9/dist-packages/ultralytics-8.0.55-py3.9.egg
# Extracting ultralytics-8.0.55-py3.9.egg to /usr/local/lib/python3.9/dist-packages
# Adding ultralytics 8.0.55 to easy-install.pth file
# Installing ultralytics script to /usr/local/bin
# Installing yolo script to /usr/local/bin
#
# Installed /usr/local/lib/python3.9/dist-packages/ultralytics-8.0.55-py3.9.egg
# Processing dependencies for ultralytics==8.0.55
# Searching for sentry_sdk
# Reading https://pypi.org/simple/sentry_sdk/
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning:  is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc9 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc10 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc11 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc12 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc13 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc14 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc15 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0rc16 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.1.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.2.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.2.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.9 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.10 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.3.11 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.4.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.4.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.4.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.5.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.5.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.5.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.5.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.6.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.20.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-0.20.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.0.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.1.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.2.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.3.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.3.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.4.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.4.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.4.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.4.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.9 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.10 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.11 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.5.12 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.6.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.7.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.7.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.7.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.8.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.2 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.3 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.4 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.5 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.6 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.7 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.8 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.9 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.9.10 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.10.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.10.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.11.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.11.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.12.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.12.1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.13.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.14.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.15.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.16.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: sdk-1.17.0 is an invalid version and will not be supported in a future release
#   warnings.warn(
# Downloading https://files.pythonhosted.org/packages/e5/c5/669e528a5ccb16c22ef239a8dc9e51c855a2bcea548e8d71808ce1438045/sentry_sdk-1.17.0-py2.py3-none-any.whl#sha256=3c4e898f7a3edf5a2042cd0dcab6ee124e2112189228c272c08ad15d3850c201
# Best match: sentry-sdk 1.17.0
# Processing sentry_sdk-1.17.0-py2.py3-none-any.whl
# Installing sentry_sdk-1.17.0-py2.py3-none-any.whl to /usr/local/lib/python3.9/dist-packages
# Adding sentry-sdk 1.17.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.9/dist-packages/sentry_sdk-1.17.0-py3.9.egg
# Searching for thop==0.1.1.post2209072238
# Best match: thop 0.1.1.post2209072238
# Adding thop 0.1.1.post2209072238 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for psutil==5.9.4
# Best match: psutil 5.9.4
# Adding psutil 5.9.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for seaborn==0.12.2
# Best match: seaborn 0.12.2
# Adding seaborn 0.12.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pandas==1.4.4
# Best match: pandas 1.4.4
# Adding pandas 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for tqdm==4.65.0
# Best match: tqdm 4.65.0
# Adding tqdm 4.65.0 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for torchvision==0.14.1+cu116
# Best match: torchvision 0.14.1+cu116
# Adding torchvision 0.14.1+cu116 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for torch==1.13.1+cu116
# Best match: torch 1.13.1+cu116
# Adding torch 1.13.1+cu116 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for scipy==1.10.1
# Best match: scipy 1.10.1
# Adding scipy 1.10.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for requests==2.27.1
# Best match: requests 2.27.1
# Adding requests 2.27.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for PyYAML==6.0
# Best match: PyYAML 6.0
# Adding PyYAML 6.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for Pillow==8.4.0
# Best match: Pillow 8.4.0
# Adding Pillow 8.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for opencv-python==4.7.0.72
# Best match: opencv-python 4.7.0.72
# Adding opencv-python 4.7.0.72 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for numpy==1.22.4
# Best match: numpy 1.22.4
# Adding numpy 1.22.4 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.9 script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for matplotlib==3.7.1
# Best match: matplotlib 3.7.1
# Adding matplotlib 3.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for urllib3==1.26.15
# Best match: urllib3 1.26.15
# Adding urllib3 1.26.15 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for certifi==2022.12.7
# Best match: certifi 2022.12.7
# Adding certifi 2022.12.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pytz==2022.7.1
# Best match: pytz 2022.7.1
# Adding pytz 2022.7.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for typing-extensions==4.5.0
# Best match: typing-extensions 4.5.0
# Adding typing-extensions 4.5.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for idna==3.4
# Best match: idna 3.4
# Adding idna 3.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for charset-normalizer==2.0.12
# Best match: charset-normalizer 2.0.12
# Adding charset-normalizer 2.0.12 to easy-install.pth file
# Installing normalizer script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for importlib-resources==5.12.0
# Best match: importlib-resources 5.12.0
# Adding importlib-resources 5.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for packaging==23.0
# Best match: packaging 23.0
# Adding packaging 23.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for kiwisolver==1.4.4
# Best match: kiwisolver 1.4.4
# Adding kiwisolver 1.4.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for fonttools==4.39.2
# Best match: fonttools 4.39.2
# Adding fonttools 4.39.2 to easy-install.pth file
# Installing fonttools script to /usr/local/bin
# Installing pyftmerge script to /usr/local/bin
# Installing pyftsubset script to /usr/local/bin
# Installing ttx script to /usr/local/bin
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for contourpy==1.0.7
# Best match: contourpy 1.0.7
# Adding contourpy 1.0.7 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Searching for zipp==3.15.0
# Best match: zipp 3.15.0
# Adding zipp 3.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.9/dist-packages
# Finished processing dependencies for ultralytics==8.0.55

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ultralytics
#   Downloading ultralytics-8.0.55-py3-none-any.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.5/485.5 KB 33.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (2.27.1)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (0.14.1+cu116)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (1.4.4)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (1.13.1+cu116)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (1.22.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (1.10.1)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.17.0-py2.py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (4.39.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (23.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics) (2.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics) (4.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.2.2->ultralytics) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Installing collected packages: sentry-sdk, ultralytics
# Successfully installed sentry-sdk-1.17.0 ultralytics-8.0.55

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.4/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/autism.zip /content/ultralytics/

# %%
# !unzip autism.zip
# Out:
# Archive:  autism.zip
#    creating: autism/
#    creating: autism/test/
#    creating: autism/test/Autistic/
#   inflating: autism/test/Autistic/001.jpg
#   inflating: autism/test/Autistic/002.jpg
#   inflating: autism/test/Autistic/003.jpg
#   inflating: autism/test/Autistic/004.jpg
#   inflating: autism/test/Autistic/005.jpg
#   inflating: autism/test/Autistic/006.jpg
#   inflating: autism/test/Autistic/007.jpg
#   inflating: autism/test/Autistic/008.jpg
#   inflating: autism/test/Autistic/009.jpg
#   inflating: autism/test/Autistic/010.jpg
#   inflating: autism/test/Autistic/011.jpg
#   inflating: autism/test/Autistic/012.jpg
#   inflating: autism/test/Autistic/013.jpg
#   inflating: autism/test/Autistic/014.jpg
#   inflating: autism/test/Autistic/015.jpg
#   inflating: autism/test/Autistic/016.jpg
#   inflating: autism/test/Autistic/017.jpg
#   inflating: autism/test/Autistic/018.jpg
#   inflating: autism/test/Autistic/019.jpg
#   inflating: autism/test/Autistic/020.jpg
#   inflating: autism/test/Autistic/021.jpg
#   inflating: autism/test/Autistic/022.jpg
#   inflating: autism/test/Autistic/023.jpg
#   inflating: autism/test/Autistic/024.jpg
#   inflating: autism/test/Autistic/025.jpg
#   inflating: autism/test/Autistic/026.jpg
#   inflating: autism/test/Autistic/027.jpg
#   inflating: autism/test/Autistic/028.jpg
#   inflating: autism/test/Autistic/029.jpg
#   inflating: autism/test/Autistic/030.jpg
#   inflating: autism/test/Autistic/031.jpg
#   inflating: autism/test/Autistic/032.jpg
#   inflating: autism/test/Autistic/033.jpg
#   inflating: autism/test/Autistic/034.jpg
#   inflating: autism/test/Autistic/035.jpg
#   inflating: autism/test/Autistic/036.jpg
#   inflating: autism/test/Autistic/037.jpg
#   inflating: autism/test/Autistic/038.jpg
#   inflating: autism/test/Autistic/039.jpg
#   inflating: autism/test/Autistic/040.jpg
#   inflating: autism/test/Autistic/041.jpg
#   inflating: autism/test/Autistic/042.jpg
#   inflating: autism/test/Autistic/043.jpg
#   inflating: autism/test/Autistic/044.jpg
#   inflating: autism/test/Autistic/045.jpg
#   inflating: autism/test/Autistic/046.jpg
#   inflating: autism/test/Autistic/047.jpg
#   inflating: autism/test/Autistic/048.jpg
#   inflating: autism/test/Autistic/049.jpg
#   inflating: autism/test/Autistic/050.jpg
#   inflating: autism/test/Autistic/051.jpg
#   inflating: autism/test/Autistic/052.jpg
#   inflating: autism/valid/Non_Autistic/27.jpg
#   inflating: autism/valid/Non_Autistic/28.jpg
#   inflating: autism/valid/Non_Autistic/29.jpg
#   inflating: autism/valid/Non_Autistic/30.jpg
#   inflating: autism/valid/Non_Autistic/31.jpg
#   inflating: autism/valid/Non_Autistic/32.jpg
#   inflating: autism/valid/Non_Autistic/33.png
#   inflating: autism/valid/Non_Autistic/34.jpg
#   inflating: autism/valid/Non_Autistic/35.jpg
#   inflating: autism/valid/Non_Autistic/36.jpg
#   inflating: autism/valid/Non_Autistic/37.jpg
#   inflating: autism/valid/Non_Autistic/38.jpg
#   inflating: autism/valid/Non_Autistic/39.jpg
#   inflating: autism/valid/Non_Autistic/40.jpg

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/content/ultralytics/autism epochs=4 optimizer = RMSProp plots = True lr0 = 0.001 lr0= 0.001 momentum=0.97 imgsz=128
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# yolo/engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=/content/ultralytics/autism, epochs=4, patience=50, batch=16, imgsz=128, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=RMSProp, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.97, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs/classify/train6
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.Classify              [256, 2]
# YOLOv8n-cls summary: 99 layers, 1440850 parameters, 1440850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# 2023-03-22 13:56:55.817591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-22 13:56:57.110177: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-22 13:56:57.110353: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-22 13:56:57.110378: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# TensorBoard: Start with 'tensorboard --logdir runs/classify/train6', view at http://localhost:6006/
# optimizer: RMSprop(lr=0.001) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias
# albumentations: RandomResizedCrop(p=1.0, height=128, width=128, scale=(0.08, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[0, 0]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Image sizes 128 train, 128 val
# Using 0 dataloader workers
# Logging results to runs/classify/train6
# Starting training for 4 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#         1/4         0G     0.2044         14        128: 100% 166/166 [01:01<00:00,  2.70it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:02<00:00,  2.20it/s]
#                    all      0.589          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#         2/4         0G     0.1757         14        128: 100% 166/166 [00:59<00:00,  2.77it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:03<00:00,  1.63it/s]
#                    all        0.5          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#         3/4         0G     0.1819         14        128: 100% 166/166 [00:59<00:00,  2.80it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:03<00:00,  1.43it/s]
#                    all      0.532          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#         4/4         0G     0.1757         14        128: 100% 166/166 [00:59<00:00,  2.79it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:02<00:00,  2.03it/s]
#                    all      0.614          1
#
# 4 epochs completed in 0.070 hours.
# Optimizer stripped from runs/classify/train6/weights/last.pt, 3.0MB
# Optimizer stripped from runs/classify/train6/weights/best.pt, 3.0MB
# Results saved to runs/classify/train6

# %%
# !ls -la /content/ultralytics/runs/classify/train6/
# Out:
# total 52
# drwxr-xr-x  3 root root  4096 Mar 22 13:58 .
# drwxr-xr-x 16 root root  4096 Mar 22 13:56 ..
# -rw-r--r--  1 root root  1378 Mar 22 13:56 args.yaml
# -rw-r--r--  1 root root 32568 Mar 22 14:01 events.out.tfevents.1679493418.f5542c32f5e5.9973.0
# -rw-r--r--  1 root root   960 Mar 22 14:01 results.csv
# drwxr-xr-x  2 root root  4096 Mar 22 13:58 weights

# %%
# !cat /content/ultralytics/runs/classify/train6/results.csv | head -10
# Out:
#                   epoch,             train/loss,  metrics/accuracy_top1,  metrics/accuracy_top5,               val/loss,                 lr/pg0,                 lr/pg1,                 lr/pg2
#                       0,                0.20436,                0.58929,                      1,                 0.5887,               0.067199,             0.00033133,             0.00033133
#                       1,                0.17571,                    0.5,                      1,                0.61109,               0.034034,             0.00050016,             0.00050016
#                       2,                0.18188,                0.53214,                      1,                0.58134,             0.00070479,             0.00050399,             0.00050399
#                       3,                0.17574,                0.61429,                      1,                0.58435,              0.0002575,              0.0002575,              0.0002575

# %%
# !pip install -e ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/ultralytics/ultralytics
# ERROR: file:///content/ultralytics/ultralytics does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.8/107.7 GB disk)

# %%
# !yolo task=classify mode=val model=/content/ultralytics/runs/classify/train6/weights/best.pt data=/content/ultralytics/autism/  conf=0.5 plots= True save_txt = True
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
#                classes   top1_acc   top5_acc: 100% 18/18 [00:02<00:00,  8.20it/s]
#                    all      0.614          1
# Speed: 0.0ms preprocess, 4.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val10

# %%
# !yolo task=classify mode=val model=./runs/detect/train/weights/best.pt data=./datasets/boat.yaml conf=0.5

# %%
Image(filename=f'/content/ultralytics/runs/classify/train2/results.png', height=800)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-7027e93fccd2> in <module>
# ----> 1 Image(filename=f'/content/ultralytics/runs/classify/train2/results.png', height=800)
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1201         self.retina = retina
#    1202         self.unconfined = unconfined
# -> 1203         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1204                 metadata=metadata)
#    1205
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     625             self.metadata = {}
#     626
# --> 627         self.reload()
#     628         self._check_data()
#     629
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/display.py in reload(self)
#    1233         """Reload the raw data from file or URL."""
#    1234         if self.embed:
# -> 1235             super(Image,self).reload()
#    1236             if self.retina:
#    1237                 self._retina_shape()
#
# /usr/local/lib/python3.9/dist-packages/IPython/core/display.py in reload(self)
#     650         """Reload the raw data from file or URL."""
#     651         if self.filename is not None:
# --> 652             with open(self.filename, self._read_flags) as f:
#     653                 self.data = f.read()
#     654         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ultralytics/runs/classify/train2/results.png'

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data=/content/ultralytics/autism epochs=10 imgsz=128
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=classify, mode=train, model=yolov8n-cls.pt, data=/content/ultralytics/autism, epochs=10, patience=50, batch=16, imgsz=128, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/content/ultralytics/runs/classify/train
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    332802  ultralytics.nn.modules.Classify              [256, 2]
# YOLOv8n-cls summary: 99 layers, 1440850 parameters, 1440850 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# 2023-03-22 05:31:25.253603: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-22 05:31:26.086336: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-22 05:31:26.086456: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-22 05:31:26.086476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# TensorBoard: Start with 'tensorboard --logdir /content/ultralytics/runs/classify/train', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 298MB/s]
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias
# albumentations: RandomResizedCrop(p=1.0, height=128, width=128, scale=(0.08, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=1), HorizontalFlip(p=0.5), ColorJitter(p=0.5, brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[0, 0]), Normalize(p=1.0, mean=(0.0, 0.0, 0.0), std=(1.0, 1.0, 1.0), max_pixel_value=255.0), ToTensorV2(always_apply=True, p=1.0, transpose_mask=False)
# Image sizes 128 train, 128 val
# Using 2 dataloader workers
# Logging results to /content/ultralytics/runs/classify/train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/10    0.0902G     0.1731         14        128: 100% 166/166 [00:14<00:00, 11.31it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 32.48it/s]
#                    all      0.564          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/10     0.126G     0.1704         14        128: 100% 166/166 [00:12<00:00, 12.97it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 12.31it/s]
#                    all      0.593          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/10     0.126G      0.167         14        128: 100% 166/166 [00:11<00:00, 14.51it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 12.61it/s]
#                    all      0.657          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/10     0.126G      0.164         14        128: 100% 166/166 [00:11<00:00, 14.28it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 41.49it/s]
#                    all      0.546          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/10     0.126G     0.1625         14        128: 100% 166/166 [00:12<00:00, 12.83it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 26.96it/s]
#                    all      0.711          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/10     0.126G     0.1597         14        128: 100% 166/166 [00:12<00:00, 13.01it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 20.89it/s]
#                    all      0.729          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/10     0.126G     0.1567         14        128: 100% 166/166 [00:12<00:00, 12.95it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 33.84it/s]
#                    all      0.736          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/10     0.126G     0.1506         14        128: 100% 166/166 [00:13<00:00, 12.48it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 35.39it/s]
#                    all      0.839          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/10     0.126G     0.1483         14        128: 100% 166/166 [00:12<00:00, 12.89it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 27.48it/s]
#                    all      0.807          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/10     0.126G     0.1479         14        128: 100% 166/166 [00:12<00:00, 12.95it/s]
#                classes   top1_acc   top5_acc: 100% 5/5 [00:00<00:00, 31.93it/s]
#                    all      0.836          1
#
# 10 epochs completed in 0.037 hours.
# Optimizer stripped from /content/ultralytics/runs/classify/train/weights/last.pt, 3.0MB
# Optimizer stripped from /content/ultralytics/runs/classify/train/weights/best.pt, 3.0MB
# Results saved to /content/ultralytics/runs/classify/train

# %%
# !yolo task=classify mode=predict model=/content/ultralytics/runs/classify/train6/weights/best.pt conf=0.25 source=./autism/test/Autistic/  plots=True save= True save_hybrid = True save_json = True
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CPU
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1
jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 12.1ms
# image 34/140 /content/ultralytics/autism/test/Autistic/034.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 11.7ms
# image 35/140 /content/ultralytics/autism/test/Autistic/035.jpg: 128x128 Non_Autistic 0.58, Autistic 0.42, 13.9ms
# image 36/140 /content/ultralytics/autism/test/Autistic/036.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 12.1ms
# image 37/140 /content/ultralytics/autism/test/Autistic/037.jpg: 128x128 Non_Autistic 0.52, Autistic 0.48, 10.8ms
# image 38/140 /content/ultralytics/autism/test/Autistic/038.jpg: 128x128 Autistic 0.66, Non_Autistic 0.34, 10.9ms
# image 39/140 /content/ultralytics/autism/test/Autistic/039.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 11.5ms
# image 40/140 /content/ultralytics/autism/test/Autistic/040.jpg: 128x128 Autistic 0.51, Non_Autistic 0.49, 10.8ms
# image 41/140 /content/ultralytics/autism/test/Autistic/041.jpg: 128x128 Autistic 0.60, Non_Autistic 0.40, 10.8ms
# image 42/140 /content/ultralytics/autism/test/Autistic/042.jpg: 128x128 Autistic 0.51, Non_Autistic 0.49, 10.8ms
# image 43/140 /content/ultralytics/autism/test/Autistic/043.jpg: 128x128 Non_Autistic 0.64, Autistic 0.36, 11.3ms
# image 44/140 /content/ultralytics/autism/test/Autistic/044.jpg: 128x128 Non_Autistic 0.66, Autistic 0.34, 11.8ms
# image 45/140 /content/ultralytics/autism/test/Autistic/045.jpg: 128x128 Non_Autistic 0.66, Autistic 0.34, 11.3ms
# image 46/140 /content/ultralytics/autism/test/Autistic/046.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 11.5ms
# image 47/140 /content/ultralytics/autism/test/Autistic/047.jpg: 128x128 Non_Autistic 0.56, Autistic 0.44, 11.0ms
# image 48/140 /content/ultralytics/autism/test/Autistic/048.jpg: 128x128 Autistic 0.54, Non_Autistic 0.46, 11.0ms
# image 49/140 /content/ultralytics/autism/test/Autistic/049.jpg: 128x128 Non_Autistic 0.62, Autistic 0.38, 10.9ms
# image 50/140 /content/ultralytics/autism/test/Autistic/050.jpg: 128x128 Non_Autistic 0.66, Autistic 0.34, 13.2ms
# image 51/140 /content/ultralytics/autism/test/Autistic/051.jpg: 128x128 Autistic 0.56, Non_Autistic 0.44, 11.0ms
# image 52/140 /content/ultralytics/autism/test/Autistic/052.jpg: 128x128 Autistic 0.53, Non_Autistic 0.47, 11.2ms
# image 53/140 /content/ultralytics/autism/test/Autistic/053.jpg: 128x128 Autistic 0.59, Non_Autistic 0.41, 11.0ms
# image 54/140 /content/ultralytics/autism/test/Autistic/054.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 15.3ms
# image 55/140 /content/ultralytics/autism/test/Autistic/055.jpg: 128x128 Non_Autistic 0.53, Autistic 0.47, 11.7ms
# image 56/140 /content/ultralytics/autism/test/Autistic/056.jpg: 128x128 Non_Autistic 0.58, Autistic 0.42, 10.9ms
# image 57/140 /content/ultralytics/autism/test/Autistic/057.jpg: 128x128 Non_Autistic 0.58, Autistic 0.42, 11.0ms
# image 58/140 /content/ultralytics/autism/test/Autistic/058.jpg: 128x128 Non_Autistic 0.62, Autistic 0.38, 11.0ms
# image 59/140 /content/ultralytics/autism/test/Autistic/059.jpg: 128x128 Non_Autistic 0.52, Autistic 0.48, 14.8ms
# image 60/140 /content/ultralytics/autism/test/Autistic/060.jpg: 128x128 Non_Autistic 0.60, Autistic 0.40, 11.0ms
# image 61/140 /content/ultralytics/autism/test/Autistic/061.jpg: 128x128 Non_Autistic 0.62, Autistic 0.38, 12.0ms
# image 62/140 /content/ultralytics/autism/test/Autistic/062.jpg: 128x128 Non_Autistic 0.53, Autistic 0.47, 11.3ms
# image 63/140 /content/ultralytics/autism/test/Autistic/063.jpg: 128x128 Non_Autistic 0.55, Autistic 0.45, 11.0ms
# image 64/140 /content/ultralytics/autism/test/Autistic/064.jpg: 128x128 Non_Autistic 0.55, Autistic 0.45, 10.9ms
# image 65/140 /content/ultralytics/autism/test/Autistic/065.jpg: 128x128 Non_Autistic 0.50, Autistic 0.50, 12.0ms
# image 66/140 /content/ultralytics/autism/test/Autistic/066.jpg: 128x128 Non_Autistic 0.53, Autistic 0.47, 18.5ms
# image 67/140 /content/ultralytics/autism/test/Autistic/067.jpg: 128x128 Autistic 0.77, Non_Autistic 0.23, 11.5ms
# image 68/140 /content/ultralytics/autism/test/Autistic/068.jpg: 128x128 Autistic 0.60, Non_Autistic 0.40, 12.2ms
# image 69/140 /content/ultralytics/autism/test/Autistic/069.jpg: 128x128 Non_Autistic 0.55, Autistic 0.45, 11.0ms
# image 70/140 /content/ultralytics/autism/test/Autistic/070.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 11.8ms
# image 71/140 /content/ultralytics/autism/test/Autistic/071.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 10.9ms
# image 72/140 /content/ultralytics/autism/test/Autistic/072.jpg: 128x128 Non_Autistic 0.50, Autistic 0.50, 11.0ms
# image 73/140 /content/ultralytics/autism/test/Autistic/073.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 10.8ms
# image 74/140 /content/ultralytics/autism/test/Autistic/074.jpg: 128x128 Non_Autistic 0.55, Autistic 0.45, 10.7ms
# image 75/140 /content/ultralytics/autism/test/Autistic/075.jpg: 128x128 Non_Autistic 0.58, Autistic 0.42, 10.8ms
# image 76/140 /content/ultralytics/autism/test/Autistic/076.jpg: 128x128 Non_Autistic 0.56, Autistic 0.44, 11.9ms
# image 77/140 /content/ultralytics/autism/test/Autistic/077.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 14.4ms
# image 78/140 /content/ultralytics/autism/test/Autistic/078.jpg: 128x128 Non_Autistic 0.52, Autistic 0.48, 11.5ms
# image 79/140 /content/ultralytics/autism/test/Autistic/079.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 11.9ms
# image 80/140 /content/ultralytics/autism/test/Autistic/080.jpg: 128x128 Non_Autistic 0.66, Autistic 0.34, 11.5ms
# image 81/140 /content/ultralytics/autism/test/Autistic/081.jpg: 128x128 Non_Autistic 0.61, Autistic 0.39, 11.0ms
# image 82/140 /content/ultralytics/autism/test/Autistic/082.jpg: 128x128 Autistic 0.65, Non_Autistic 0.35, 10.9ms
# image 83/140 /content/ultralytics/autism/test/Autistic/083.jpg: 128x128 Non_Autistic 0.64, Autistic 0.36, 11.6ms
# image 84/140 /content/ultralytics/autism/test/Autistic/084.jpg: 128x128 Non_Autistic 0.55, Autistic 0.45, 10.8ms
# image 85/140 /content/ultralytics/autism/test/Autistic/085.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 16.2ms
# image 86/140 /content/ultralytics/autism/test/Autistic/086.jpg: 128x128 Autistic 0.54, Non_Autistic 0.46, 10.7ms
# image 87/140 /content/ultralytics/autism/test/Autistic/087.jpg: 128x128 Non_Autistic 0.62, Autistic 0.38, 12.9ms
# image 88/140 /content/ultralytics/autism/test/Autistic/088.jpg: 128x128 Non_Autistic 0.64, Autistic 0.36, 11.1ms
# image 89/140 /content/ultralytics/autism/test/Autistic/089.jpg: 128x128 Non_Autistic 0.60, Autistic 0.40, 12.0ms
# image 90/140 /content/ultralytics/autism/test/Autistic/090.jpg: 128x128 Non_Autistic 0.56, Autistic 0.44, 12.1ms
# image 91/140 /content/ultralytics/autism/test/Autistic/091.jpg: 128x128 Autistic 0.54, Non_Autistic 0.46, 12.0ms
# image 92/140 /content/ultralytics/autism/test/Autistic/092.jpg: 128x128 Non_Autistic 0.57, Autistic 0.43, 11.9ms
# image 93/140 /content/ultralytics/autism/test/Autistic/093.jpg: 128x128 Non_Autistic 0.59, Autistic 0.41, 11.8ms
# image 94/140 /content/ultralytics/autism/test/Autistic/094.jpg: 128x128 Non_Autistic 0.53, Autistic 0.47, 12.0ms
# image 95/140 /content/ultralytics/autism/test/Autistic/095.jpg: 128x128 Autistic 0.51, Non_Autistic 0.49, 11.3ms
# image 96/140 /content/ultralytics/autism/test/Autistic/096.jpg: 128x128 Autistic 0.58, Non_Autistic 0.42, 12.7ms
# image 97/140 /content/ultralytics/autism/test/Autistic/097.jpg: 128x128 Autistic 0.53, Non_Autistic 0.47, 7.6ms
# image 98/140 /content/ultralytics/autism/test/Autistic/098.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37,
jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 7.2ms
# image 130/140 /content/ultralytics/autism/test/Autistic/130.jpg: 128x128 Non_Autistic 0.59, Autistic 0.41, 10.5ms
# image 131/140 /content/ultralytics/autism/test/Autistic/131.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 7.6ms
# image 132/140 /content/ultralytics/autism/test/Autistic/132.jpg: 128x128 Non_Autistic 0.66, Autistic 0.34, 7.3ms
# image 133/140 /content/ultralytics/autism/test/Autistic/133.jpg: 128x128 Non_Autistic 0.68, Autistic 0.32, 7.3ms
# image 134/140 /content/ultralytics/autism/test/Autistic/134.jpg: 128x128 Non_Autistic 0.63, Autistic 0.37, 8.5ms
# image 135/140 /content/ultralytics/autism/test/Autistic/135.jpg: 128x128 Autistic 0.63, Non_Autistic 0.37, 7.1ms
# image 136/140 /content/ultralytics/autism/test/Autistic/136.jpg: 128x128 Non_Autistic 0.64, Autistic 0.36, 7.3ms
# image 137/140 /content/ultralytics/autism/test/Autistic/137.jpg: 128x128 Non_Autistic 0.52, Autistic 0.48, 7.1ms
# image 138/140 /content/ultralytics/autism/test/Autistic/138.jpg: 128x128 Non_Autistic 0.57, Autistic 0.43, 7.2ms
# image 139/140 /content/ultralytics/autism/test/Autistic/139.jpg: 128x128 Autistic 0.61, Non_Autistic 0.39, 7.4ms
# image 140/140 /content/ultralytics/autism/test/Autistic/140.jpg: 128x128 Autistic 0.53, Non_Autistic 0.47, 13.2ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
# Results saved to runs/classify/predict2

# %%
# Ultralytics YOLO 🚀, GPL-3.0 license

import contextlib
import math
from pathlib import Path

import cv2
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image, ImageDraw, ImageFont
from PIL import __version__ as pil_version

from ultralytics.yolo.utils import LOGGER, TryExcept, threaded

# from .checks import check_font, check_version, is_ascii
# from .files import increment_path
# from .ops import clip_coords, scale_image, xywh2xyxy, xyxy2xywh

matplotlib.rc('font', **{'size': 11})
matplotlib.use('Agg')  # for writing to files only


# class Colors:
#     # Ultralytics color palette https://ultralytics.com/
#     def __init__(self):
#         # hex = matplotlib.colors.TABLEAU_COLORS.values()
#         hexs = ('FF3838', 'FF9D97', 'FF701F', 'FFB21D', 'CFD231', '48F90A', '92CC17', '3DDB86', '1A9334', '00D4BB',
#                 '2C99A8', '00C2FF', '344593', '6473FF', '0018EC', '8438FF', '520085', 'CB38FF', 'FF95C8', 'FF37C7')
#         self.palette = [self.hex2rgb(f'#{c}') for c in hexs]
#         self.n = len(self.palette)

#     def __call__(self, i, bgr=False):
#         c = self.palette[int(i) % self.n]
#         return (c[2], c[1], c[0]) if bgr else c

#     @staticmethod
#     def hex2rgb(h):  # rgb order (PIL)
#         return tuple(int(h[1 + i:1 + i + 2], 16) for i in (0, 2, 4))


# colors = Colors()  # create instance for 'from utils.plots import colors'


# class Annotator:
#     # YOLOv8 Annotator for train/val mosaics and jpgs and detect/hub inference annotations
#     def __init__(self, im, line_width=None, font_size=None, font='Arial.ttf', pil=False, example='abc'):
#         assert im.data.contiguous, 'Image not contiguous. Apply np.ascontiguousarray(im) to Annotator() input images.'
#         non_ascii = not is_ascii(example)  # non-latin labels, i.e. asian, arabic, cyrillic
#         self.pil = pil or non_ascii
#         if self.pil:  # use PIL
#             self.pil_9_2_0_check = check_version(pil_version, '9.2.0')  # deprecation check
#             self.im = im if isinstance(im, Image.Image) else Image.fromarray(im)
#             self.draw = ImageDraw.Draw(self.im)
#             try:
#                 font = check_font('Arial.Unicode.ttf' if non_ascii else font)
#                 size = font_size or max(round(sum(self.im.size) / 2 * 0.035), 12)
#                 self.font = ImageFont.truetype(str(font), size)
#             except Exception:
#                 self.font = ImageFont.load_default()
#         else:  # use cv2
#             self.im = im
#         self.lw = line_width or max(round(sum(im.shape) / 2 * 0.003), 2)  # line width

#     def box_label(self, box, label='', color=(128, 128, 128), txt_color=(255, 255, 255)):
#         # Add one xyxy box to image with label
#         if isinstance(box, torch.Tensor):
#             box = box.tolist()
#         if self.pil or not is_ascii(label):
#             self.draw.rectangle(box, width=self.lw, outline=color)  # box
#             if label:
#                 if self.pil_9_2_0_check:
#                     _, _, w, h = self.font.getbbox(label)  # text width, height (New)
#                 else:
#                     w, h = self.font.getsize(label)  # text width, height (Old, deprecated in 9.2.0)
#                 outside = box[1] - h >= 0  # label fits outside box
#                 self.draw.rectangle(
#                     (box[0], box[1] - h if outside else box[1], box[0] + w + 1,
#                      box[1] + 1 if outside else box[1] + h + 1),
#                     fill=color,
#                 )
#                 # self.draw.text((box[0], box[1]), label, fill=txt_color, font=self.font, anchor='ls')  # for PIL>8.0
#                 self.draw.text((box[0], box[1] - h if outside else box[1]), label, fill=txt_color, font=self.font)
#         else:  # cv2
#             p1, p2 = (int(box[0]), int(box[1])), (int(box[2]), int(box[3]))
#             cv2.rectangle(self.im, p1, p2, color, thickness=self.lw, lineType=cv2.LINE_AA)
#             if label:
#                 tf = max(self.lw - 1, 1)  # font thickness
#                 w, h = cv2.getTextSize(label, 0, fontScale=self.lw / 3, thickness=tf)[0]  # text width, height
#                 outside = p1[1] - h >= 3
#                 p2 = p1[0] + w, p1[1] - h - 3 if outside else p1[1] + h + 3
#                 cv2.rectangle(self.im, p1, p2, color, -1, cv2.LINE_AA)  # filled
#                 cv2.putText(self.im,
#                             label, (p1[0], p1[1] - 2 if outside else p1[1] + h + 2),
#                             0,
#                             self.lw / 3,
#                             txt_color,
#                             thickness=tf,
#                             lineType=cv2.LINE_AA)

#     def masks(self, masks, colors, im_gpu, alpha=0.5, retina_masks=False):
#         """Plot masks at once.
#         Args:
#             masks (tensor): predicted masks on cuda, shape: [n, h, w]
#             colors (List[List[Int]]): colors for predicted masks, [[r, g, b] * n]
#             im_gpu (tensor): img is in cuda, shape: [3, h, w], range: [0, 1]
#             alpha (float): mask transparency: 0.0 fully transparent, 1.0 opaque
#         """
#         if self.pil:
#             # convert to numpy first
#             self.im = np.asarray(self.im).copy()
#         if len(masks) == 0:
#             self.im[:] = im_gpu.permute(1, 2, 0).contiguous().cpu().numpy() * 255
#         if im_gpu.device != masks.device:
#             im_gpu = im_gpu.to(masks.device)
#         colors = torch.tensor(colors, device=masks.device, dtype=torch.float32) / 255.0
#         colors = colors[:, None, None]  # shape(n,1,1,3)
#         masks = masks.unsqueeze(3)  # shape(n,h,w,1)
#         masks_color = masks * (colors * alpha)  # shape(n,h,w,3)

#         inv_alph_masks = (1 - masks * alpha).cumprod(0)  # shape(n,h,w,1)
#         mcs = (masks_color * inv_alph_masks).sum(0) * 2  # mask color summand shape(n,h,w,3)

#         im_gpu = im_gpu.flip(dims=[0])  # flip channel
#         im_gpu = im_gpu.permute(1, 2, 0).contiguous()  # shape(h,w,3)
#         im_gpu = im_gpu * inv_alph_masks[-1] + mcs
#         im_mask = (im_gpu * 255)
#         im_mask_np = im_mask.byte().cpu().numpy()
#         self.im[:] = im_mask_np if retina_masks else scale_image(im_gpu.shape, im_mask_np, self.im.shape)
#         if self.pil:
#             # convert im back to PIL and update draw
#             self.fromarray(self.im)

#     def rectangle(self, xy, fill=None, outline=None, width=1):
#         # Add rectangle to image (PIL-only)
#         self.draw.rectangle(xy, fill, outline, width)

#     def text(self, xy, text, txt_color=(255, 255, 255), anchor='top'):
#         # Add text to image (PIL-only)
#         if anchor == 'bottom':  # start y from font bottom
#             w, h = self.font.getsize(text)  # text width, height
#             xy[1] += 1 - h
#         if self.pil:
#             self.draw.text(xy, text, fill=txt_color, font=self.font)
#         else:
#             tf = max(self.lw - 1, 1)  # font thickness
#             cv2.putText(self.im, text, xy, 0, self.lw / 3, txt_color, thickness=tf, lineType=cv2.LINE_AA)

#     def fromarray(self, im):
#         # Update self.im from a numpy array
#         self.im = im if isinstance(im, Image.Image) else Image.fromarray(im)
#         self.draw = ImageDraw.Draw(self.im)

#     def result(self):
#         # Return annotated image as array
#         return np.asarray(self.im)


# @TryExcept()  # known issue https://github.com/ultralytics/yolov5/issues/5395
# def plot_labels(boxes, cls, names=(), save_dir=Path('')):
#     import pandas as pd
#     import seaborn as sn

#     # plot dataset labels
#     LOGGER.info(f"Plotting labels to {save_dir / 'labels.jpg'}... ")
#     b = boxes.transpose()  # classes, boxes
#     nc = int(cls.max() + 1)  # number of classes
#     x = pd.DataFrame(b.transpose(), columns=['x', 'y', 'width', 'height'])

#     # seaborn correlogram
#     sn.pairplot(x, corner=True, diag_kind='auto', kind='hist', diag_kws=dict(bins=50), plot_kws=dict(pmax=0.9))
#     plt.savefig(save_dir / 'labels_correlogram.jpg', dpi=200)
#     plt.close()

#     # matplotlib labels
#     matplotlib.use('svg')  # faster
#     ax = plt.subplots(2, 2, figsize=(8, 8), tight_layout=True)[1].ravel()
#     y = ax[0].hist(cls, bins=np.linspace(0, nc, nc + 1) - 0.5, rwidth=0.8)
#     with contextlib.suppress(Exception):  # color histogram bars by class
#         [y[2].patches[i].set_color([x / 255 for x in colors(i)]) for i in range(nc)]  # known issue #3195
#     ax[0].set_ylabel('instances')
#     if 0 < len(names) < 30:
#         ax[0].set_xticks(range(len(names)))
#         ax[0].set_xticklabels(list(names.values()), rotation=90, fontsize=10)
#     else:
#         ax[0].set_xlabel('classes')
#     sn.histplot(x, x='x', y='y', ax=ax[2], bins=50, pmax=0.9)
#     sn.histplot(x, x='width', y='height', ax=ax[3], bins=50, pmax=0.9)

#     # rectangles
#     boxes[:, 0:2] = 0.5  # center
#     boxes = xywh2xyxy(boxes) * 2000
#     img = Image.fromarray(np.ones((2000, 2000, 3), dtype=np.uint8) * 255)
#     for cls, box in zip(cls[:1000], boxes[:1000]):
#         ImageDraw.Draw(img).rectangle(box, width=1, outline=colors(cls))  # plot
#     ax[1].imshow(img)
#     ax[1].axis('off')

#     for a in [0, 1, 2, 3]:
#         for s in ['top', 'right', 'left', 'bottom']:
#             ax[a].spines[s].set_visible(False)

#     plt.savefig(save_dir / 'labels.jpg', dpi=200)
#     matplotlib.use('Agg')
#     plt.close()


# def save_one_box(xyxy, im, file=Path('im.jpg'), gain=1.02, pad=10, square=False, BGR=False, save=True):
#     # Save image crop as {file} with crop size multiple {gain} and {pad} pixels. Save and/or return crop
#     b = xyxy2xywh(xyxy.view(-1, 4))  # boxes
#     if square:
#         b[:, 2:] = b[:, 2:].max(1)[0].unsqueeze(1)  # attempt rectangle to square
#     b[:, 2:] = b[:, 2:] * gain + pad  # box wh * gain + pad
#     xyxy = xywh2xyxy(b).long()
#     clip_coords(xyxy, im.shape)
#     crop = im[int(xyxy[0, 1]):int(xyxy[0, 3]), int(xyxy[0, 0]):int(xyxy[0, 2]), ::(1 if BGR else -1)]
#     if save:
#         file.parent.mkdir(parents=True, exist_ok=True)  # make directory
#         f = str(increment_path(file).with_suffix('.jpg'))
#         # cv2.imwrite(f, crop)  # save BGR, https://github.com/ultralytics/yolov5/issues/7007 chroma subsampling issue
#         Image.fromarray(crop[..., ::-1]).save(f, quality=95, subsampling=0)  # save RGB
#     return crop


# @threaded
# def plot_images(images,
#                 batch_idx,
#                 cls,
#                 bboxes,
#                 masks=np.zeros(0, dtype=np.uint8),
#                 paths=None,
#                 fname='images.jpg',
#                 names=None):
#     # Plot image grid with labels
#     if isinstance(images, torch.Tensor):
#         images = images.cpu().float().numpy()
#     if isinstance(cls, torch.Tensor):
#         cls = cls.cpu().numpy()
#     if isinstance(bboxes, torch.Tensor):
#         bboxes = bboxes.cpu().numpy()
#     if isinstance(masks, torch.Tensor):
#         masks = masks.cpu().numpy().astype(int)
#     if isinstance(batch_idx, torch.Tensor):
#         batch_idx = batch_idx.cpu().numpy()

#     max_size = 1920  # max image size
#     max_subplots = 16  # max image subplots, i.e. 4x4
#     bs, _, h, w = images.shape  # batch size, _, height, width
#     bs = min(bs, max_subplots)  # limit plot images
#     ns = np.ceil(bs ** 0.5)  # number of subplots (square)
#     if np.max(images[0]) <= 1:
#         images *= 255  # de-normalise (optional)

#     # Build Image
#     mosaic = np.full((int(ns * h), int(ns * w), 3), 255, dtype=np.uint8)  # init
#     for i, im in enumerate(images):
#         if i == max_subplots:  # if last batch has fewer images than we expect
#             break
#         x, y = int(w * (i // ns)), int(h * (i % ns))  # block origin
#         im = im.transpose(1, 2, 0)
#         mosaic[y:y + h, x:x + w, :] = im

#     # Resize (optional)
#     scale = max_size / ns / max(h, w)
#     if scale < 1:
#         h = math.ceil(scale * h)
#         w = math.ceil(scale * w)
#         mosaic = cv2.resize(mosaic, tuple(int(x * ns) for x in (w, h)))

#     # Annotate
#     fs = int((h + w) * ns * 0.01)  # font size
#     annotator = Annotator(mosaic, line_width=round(fs / 10), font_size=fs, pil=True, example=names)
#     for i in range(i + 1):
#         x, y = int(w * (i // ns)), int(h * (i % ns))  # block origin
#         annotator.rectangle([x, y, x + w, y + h], None, (255, 255, 255), width=2)  # borders
#         if paths:
#             annotator.text((x + 5, y + 5), text=Path(paths[i]).name[:40], txt_color=(220, 220, 220))  # filenames
#         if len(cls) > 0:
#             idx = batch_idx == i

#             boxes = xywh2xyxy(bboxes[idx, :4]).T
#             classes = cls[idx].astype('int')
#             labels = bboxes.shape[1] == 4  # labels if no conf column
#             conf = None if labels else bboxes[idx, 4]  # check for confidence presence (label vs pred)

#             if boxes.shape[1]:
#                 if boxes.max() <= 1.01:  # if normalized with tolerance 0.01
#                     boxes[[0, 2]] *= w  # scale to pixels
#                     boxes[[1, 3]] *= h
#                 elif scale < 1:  # absolute coords need scale if image scales
#                     boxes *= scale
#             boxes[[0, 2]] += x
#             boxes[[1, 3]] += y
#             for j, box in enumerate(boxes.T.tolist()):
#                 c = classes[j]
#                 color = colors(c)
#                 c = names[c] if names else c
#                 if labels or conf[j] > 0.25:  # 0.25 conf thresh
#                     label = f'{c}' if labels else f'{c} {conf[j]:.1f}'
#                     annotator.box_label(box, label, color=color)

#             # Plot masks
#             if len(masks):
#                 if idx.shape[0] == masks.shape[0]:  # overlap_masks=False
#                     image_masks = masks[idx]
#                 else:  # overlap_masks=True
#                     image_masks = masks[[i]]  # (1, 640, 640)
#                     nl = idx.sum()
#                     index = np.arange(nl).reshape(nl, 1, 1) + 1
#                     image_masks = np.repeat(image_masks, nl, axis=0)
#                     image_masks = np.where(image_masks == index, 1.0, 0.0)

#                 im = np.asarray(annotator.im).copy()
#                 for j, box in enumerate(boxes.T.tolist()):
#                     if labels or conf[j] > 0.25:  # 0.25 conf thresh
#                         color = colors(classes[j])
#                         mh, mw = image_masks[j].shape
#                         if mh != h or mw != w:
#                             mask = image_masks[j].astype(np.uint8)
#                             mask = cv2.resize(mask, (w, h))
#                             mask = mask.astype(bool)
#                         else:
#                             mask = image_masks[j].astype(bool)
#                         with contextlib.suppress(Exception):
#                             im[y:y + h, x:x + w, :][mask] = im[y:y + h, x:x + w, :][mask] * 0.4 + np.array(color) * 0.6
#                 annotator.fromarray(im)
#     annotator.im.save(fname)  # save


def plot_results(file='/content/ultralytics/runs/classify/train6/results.csv', dir='', segment=False):
    # Plot training results.csv. Usage: from utils.plots import *; plot_results('path/to/results.csv')
    import pandas as pd
    save_dir = Path(file).parent if file else Path(dir)
    if segment:
        fig, ax = plt.subplots(2, 8, figsize=(18, 6), tight_layout=True)
        index = [1, 2, 3, 4, 5, 6, 9, 10, 13, 14, 15, 16, 7, 8, 11, 12]
    else:
        fig, ax = plt.subplots(2, 5, figsize=(12, 6), tight_layout=True)
        index = [1, 2, 3, 4, 5, 8, 9, 10, 6, 7]
    ax = ax.ravel()
    files = list(save_dir.glob('results*.csv'))
    assert len(files), f'No results.csv files found in {save_dir.resolve()}, nothing to plot.'
    for f in files:
        try:
            data = pd.read_csv(f)
            s = [x.strip() for x in data.columns]
            x = data.values[:, 0]
            for i, j in enumerate(index):
                y = data.values[:, j].astype('float')
                # y[y == 0] = np.nan  # don't show zero values
                ax[i].plot(x, y, marker='.', label=f.stem, linewidth=2, markersize=8)
                ax[i].set_title(s[j], fontsize=12)
                # if j in [8, 9, 10]:  # share train and val loss y axes
                #     ax[i].get_shared_y_axes().join(ax[i], ax[i - 5])
        except Exception as e:
            LOGGER.warning(f'WARNING: Plotting error for {f}: {e}')
    ax[1].legend()
    fig.savefig(save_dir / 'results.png', dpi=200)
    plt.close()


# def output_to_target(output, max_det=300):
#     # Convert model output to target format [batch_id, class_id, x, y, w, h, conf] for plotting
#     targets = []
#     for i, o in enumerate(output):
#         box, conf, cls = o[:max_det, :6].cpu().split((4, 1, 1), 1)
#         j = torch.full((conf.shape[0], 1), i)
#         targets.append(torch.cat((j, cls, xyxy2xywh(box), conf), 1))
#     targets = torch.cat(targets, 0).numpy()
#     return targets[:, 0], targets[:, 1], targets[:, 2:]

# %%
plot_results()
# Out:
# WARNING: Plotting error for /content/ultralytics/runs/classify/train6/results.csv: index 8 is out of bounds for axis 1 with size 8

# %%
# !ls -la /content/ultralytics/runs/classify/train/
# Out:
# total 100
# drwxr-xr-x 3 root root  4096 Mar 22 05:31 .
# drwxr-xr-x 3 root root  4096 Mar 22 05:31 ..
# -rw-r--r-- 1 root root  1395 Mar 22 05:31 args.yaml
# -rw-r--r-- 1 root root 81360 Mar 22 05:33 events.out.tfevents.1679463087.04c4804601c1.3964.0
# -rw-r--r-- 1 root root  2112 Mar 22 05:33 results.csv
# drwxr-xr-x 2 root root  4096 Mar 22 05:31 weights

# %%
# !cat  /content/ultralytics/runs/classify/train/results.csv | head -10
# Out:
#                   epoch,             train/loss,  metrics/accuracy_top1,  metrics/accuracy_top5,               val/loss,                 lr/pg0,                 lr/pg1,                 lr/pg2
#                       0,                0.17309,                0.56429,                      1,                0.60498,               0.070181,              0.0033133,              0.0033133
#                       1,                0.17037,                0.59286,                      1,                0.59097,               0.039523,              0.0059886,              0.0059886
#                       2,                0.16695,                0.65714,                      1,                0.56514,              0.0082047,              0.0080039,              0.0080039
#                       3,                0.16402,                0.54643,                      1,                0.59314,                0.00703,                0.00703,                0.00703
#                       4,                0.16247,                0.71071,                      1,                0.52053,                0.00703,                0.00703,                0.00703
#                       5,                0.15975,                0.72857,                      1,                0.53738,                0.00604,                0.00604,                0.00604
#                       6,                0.15673,                0.73571,                      1,                0.51531,                0.00505,                0.00505,                0.00505
#                       7,                 0.1506,                0.83929,                      1,                0.46672,                0.00406,                0.00406,                0.00406
#                       8,                0.14828,                0.80714,                      1,                0.47444,                0.00307,                0.00307,                0.00307

# %%
# !yolo task=classify mode=val model=/content/ultralytics/runs/classify/train/weights/best.pt data=/content/ultralytics/autism
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#                classes   top1_acc   top5_acc: 100% 18/18 [00:00<00:00, 26.43it/s]
#                    all      0.836          1
# Speed: 0.0ms preprocess, 0.5ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/ultralytics/runs/classify/val3

# %%
	# !yolo task=classify mode=predict model=/content/ultralytics/runs/classify/train/weights/best.pt source='/content/ultralytics/autism/test/Autistic/'
# Out:
# Ultralytics YOLOv8.0.55 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# image 1/140 /content/ultralytics/autism/test/Autistic/001.jpg: 128x128 Autistic 0.79, Non_Autistic 0.21, 4.9ms
# image 2/140 /content/ultralytics/autism/test/Autistic/002.jpg: 128x128 Autistic 0.80, Non_Autistic 0.20, 4.4ms
# image 3/140 /content/ultralytics/autism/test/Autistic/003.jpg: 128x128 Autistic 0.64, Non_Autistic 0.36, 3.2ms
# image 4/140 /content/ultralytics/autism/test/Autistic/004.jpg: 128x128 Autistic 0.58, Non_Autistic 0.42, 3.7ms
# image 5/140 /content/ultralytics/autism/test/Autistic/005.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.1ms
# image 6/140 /content/ultralytics/autism/test/Autistic/006.jpg: 128x128 Autistic 0.81, Non_Autistic 0.19, 3.1ms
# image 7/140 /content/ultralytics/autism/test/Autistic/007.jpg: 128x128 Autistic 0.69, Non_Autistic 0.31, 3.0ms
# image 8/140 /content/ultralytics/autism/test/Autistic/008.jpg: 128x128 Autistic 0.62, Non_Autistic 0.38, 3.1ms
# image 9/140 /content/ultralytics/autism/test/Autistic/009.jpg: 128x128 Autistic 0.86, Non_Autistic 0.14, 3.0ms
# image 10/140 /content/ultralytics/autism/test/Autistic/010.jpg: 128x128 Autistic 0.90, Non_Autistic 0.10, 3.0ms
# image 11/140 /content/ultralytics/autism/test/Autistic/011.jpg: 128x128 Autistic 0.81, Non_Autistic 0.19, 3.1ms
# image 12/140 /content/ultralytics/autism/test/Autistic/012.jpg: 128x128 Non_Autistic 0.88, Autistic 0.12, 3.0ms
# image 13/140 /content/ultralytics/autism/test/Autistic/013.jpg: 128x128 Autistic 0.75, Non_Autistic 0.25, 3.0ms
# image 14/140 /content/ultralytics/autism/test/Autistic/014.jpg: 128x128 Autistic 0.54, Non_Autistic 0.46, 3.1ms
# image 15/140 /content/ultralytics/autism/test/Autistic/015.jpg: 128x128 Non_Autistic 0.53, Autistic 0.47, 3.0ms
# image 16/140 /content/ultralytics/autism/test/Autistic/016.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 3.0ms
# image 17/140 /content/ultralytics/autism/test/Autistic/017.jpg: 128x128 Autistic 0.54, Non_Autistic 0.46, 3.2ms
# image 18/140 /content/ultralytics/autism/test/Autistic/018.jpg: 128x128 Autistic 0.59, Non_Autistic 0.41, 3.0ms
# image 19/140 /content/ultralytics/autism/test/Autistic/019.jpg: 128x128 Autistic 0.74, Non_Autistic 0.26, 3.1ms
# image 20/140 /content/ultralytics/autism/test/Autistic/020.jpg: 128x128 Non_Autistic 0.74, Autistic 0.26, 3.2ms
# image 21/140 /content/ultralytics/autism/test/Autistic/021.jpg: 128x128 Autistic 0.84, Non_Autistic 0.16, 3.5ms
# image 22/140 /content/ultralytics/autism/test/Autistic/022.jpg: 128x128 Autistic 0.70, Non_Autistic 0.30, 3.2ms
# image 23/140 /content/ultralytics/autism/test/Autistic/023.jpg: 128x128 Autistic 0.84, Non_Autistic 0.16, 3.1ms
# image 24/140 /content/ultralytics/autism/test/Autistic/024.jpg: 128x128 Autistic 0.83, Non_Autistic 0.17, 3.1ms
# image 25/140 /content/ultralytics/autism/test/Autistic/025.jpg: 128x128 Autistic 0.60, Non_Autistic 0.40, 3.1ms
# image 26/140 /content/ultralytics/autism/test/Autistic/026.jpg: 128x128 Autistic 0.84, Non_Autistic 0.16, 3.0ms
# image 27/140 /content/ultralytics/autism/test/Autistic/027.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.1ms
# image 28/140 /content/ultralytics/autism/test/Autistic/028.jpg: 128x128 Autistic 0.86, Non_Autistic 0.14, 3.1ms
# image 29/140 /content/ultralytics/autism/test/Autistic/029.jpg: 128x128 Autistic 0.74, Non_Autistic 0.26, 3.2ms
# image 30/140 /content/ultralytics/autism/test/Autistic/030.jpg: 128x128 Autistic 0.76, Non_Autistic 0.24, 3.0ms
# image 31/140 /content/ultralytics/autism/test/Autistic/031.jpg: 128x128 Autistic 0.92, Non_Autistic 0.08, 6.4ms
# image 32/140 /content/ultralytics/autism/test/Autistic/032.jpg: 128x128 Autistic 0.82, Non_Autistic 0.18, 4.3ms
# image 33/140 /content/ultralytics/autism/test/Autistic/033.jpg: 128x128 Autistic 0.63, Non_Autistic 0.37, 4.3ms
# image 34/140 /content/ultralytics/autism/test/Autistic/034.jpg: 128x128 Autistic 0.72, Non_Autistic 0.28, 4.6ms
# image 35/140 /content/ultralytics/autism/test/Autistic/035.jpg: 128x128 Autistic 0.69, Non_Autistic 0.31, 3.2ms
# image 36/140 /content/ultralytics/autism/test/Autistic/036.jpg: 128x128 Autistic 0.55, Non_Autistic 0.45, 7.4ms
# image 37/140 /content/ultralytics/autism/test/Autistic/037.jpg: 128x128 Autistic 0.80, Non_Autistic 0.20, 3.2ms
# image 38/140 /content/ultralytics/autism/test/Autistic/038.jpg: 128x128 Autistic 0.79, Non_Autistic 0.21, 3.2ms
# image 39/140 /content/ultralytics/autism/test/Autistic/039.jpg: 128x128 Autistic 0.66, Non_Autistic 0.34, 3.2ms
# image 40/140 /content/ultralytics/autism/test/Autistic/040.jpg: 128x128 Autistic 0.82, Non_Autistic 0.18, 3.1ms
# image 41/140 /content/ultralytics/autism/test/Autistic/041.jpg: 128x128 Autistic 0.94, Non_Autistic 0.06, 3.1ms
# image 42/140 /content/ultralytics/autism/test/Autistic/042.jpg: 128x128 Autistic 0.88, Non_Autistic 0.12, 3.1ms
# image 43/140 /content/ultralytics/autism/test/Autistic/043.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.1ms
# image 44/140 /content/ultralytics/autism/test/Autistic/044.jpg: 128x128 Autistic 0.64, Non_Autistic 0.36, 3.1ms
# image 45/140 /content/ultralytics/autism/test/Autistic/045.jpg: 128x128 Non_Autistic 0.73, Autistic 0.27, 3.1ms
# image 46/140 /content/ultralytics/autism/test/Autistic/046.jpg: 128x128 Autistic 0.72, Non_Autistic 0.28, 3.0ms
# image 47/140 /content/ultralytics/autism/test/Autistic/047.jpg: 128x128 Autistic 0.79, Non_Autistic 0.21, 3.8ms
# image 48/140 /content/ultralytics/autism/test/Autistic/048.jpg: 128x128 Autistic 0.82, Non_Autistic 0.18, 3.0ms
# image 49/140 /content/ultralytics/autism/test/Autistic/049.jpg: 128x128 Autistic 0.81, Non_Autistic 0.19, 3.3ms
# image 50/140 /content/ultralytics/autism/test/Autistic/050.jpg: 128x128 Autistic 0.69, Non_Autistic 0.31, 3.0ms
# image 51/140 /content/ultralytics/autism/test/Autistic/051.jpg: 128x128 Autistic 0.85, Non_Autistic 0.15, 3.2ms
# image 52/140 /content/ultralytics/autism/test/Autistic/052.jpg: 128x128 Non_Autistic 0.70, Autistic 0.30, 3.1ms
# image 53/140 /content/ultralytics/autism/test/Autistic/053.jpg: 128x128 Autistic 0.78, Non_Autistic 0.22, 3.0ms
# image 54/140 /content/ultralytics/autism/test/Autistic/054.jpg: 128x128 Non_Autistic 0.61, Autistic 0.39, 3.3ms
# image 55/140 /content/ultralytics/autism/test/Autistic/055.jpg: 128x128 Autistic 0.86, Non_Autistic 0.14, 3.1ms
# image 56/140 /content/ultralytics/autism/test/Autistic/056.jpg: 128x128 Autistic 0.71, Non_Autistic 0.29, 3.0ms
# image 57/140 /content/ultralytics/autism/test/Autistic/057.jpg: 128x128 Non_Autistic 0.56, Autistic 0.44, 2.9ms
# image 58/140 /content/ultralytics/autism/test/Autistic/058.jpg: 128x128 Autistic 0.71, Non_Autistic 0.29, 3.1ms
# image 59/140 /content/ultralytics/autism/test/Autistic/059.jpg: 128x128 Autistic 0.66, Non_Autistic 0.34, 3
jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.0ms
# image 116/140 /content/ultralytics/autism/test/Autistic/116.jpg: 128x128 Autistic 0.79, Non_Autistic 0.21, 3.0ms
# image 117/140 /content/ultralytics/autism/test/Autistic/117.jpg: 128x128 Autistic 0.70, Non_Autistic 0.30, 3.4ms
# image 118/140 /content/ultralytics/autism/test/Autistic/118.jpg: 128x128 Autistic 0.65, Non_Autistic 0.35, 3.1ms
# image 119/140 /content/ultralytics/autism/test/Autistic/119.jpg: 128x128 Autistic 0.80, Non_Autistic 0.20, 3.0ms
# image 120/140 /content/ultralytics/autism/test/Autistic/120.jpg: 128x128 Autistic 0.69, Non_Autistic 0.31, 4.2ms
# image 121/140 /content/ultralytics/autism/test/Autistic/121.jpg: 128x128 Autistic 0.75, Non_Autistic 0.25, 4.2ms
# image 122/140 /content/ultralytics/autism/test/Autistic/122.jpg: 128x128 Autistic 0.93, Non_Autistic 0.07, 3.6ms
# image 123/140 /content/ultralytics/autism/test/Autistic/123.jpg: 128x128 Autistic 0.88, Non_Autistic 0.12, 3.2ms
# image 124/140 /content/ultralytics/autism/test/Autistic/124.jpg: 128x128 Autistic 0.81, Non_Autistic 0.19, 3.3ms
# image 125/140 /content/ultralytics/autism/test/Autistic/125.jpg: 128x128 Autistic 0.89, Non_Autistic 0.11, 3.2ms
# image 126/140 /content/ultralytics/autism/test/Autistic/126.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.0ms
# image 127/140 /content/ultralytics/autism/test/Autistic/127.jpg: 128x128 Autistic 0.84, Non_Autistic 0.16, 3.1ms
# image 128/140 /content/ultralytics/autism/test/Autistic/128.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.2ms
# image 129/140 /content/ultralytics/autism/test/Autistic/129.jpg: 128x128 Autistic 0.86, Non_Autistic 0.14, 3.0ms
# image 130/140 /content/ultralytics/autism/test/Autistic/130.jpg: 128x128 Autistic 0.72, Non_Autistic 0.28, 3.1ms
# image 131/140 /content/ultralytics/autism/test/Autistic/131.jpg: 128x128 Autistic 0.71, Non_Autistic 0.29, 3.1ms
# image 132/140 /content/ultralytics/autism/test/Autistic/132.jpg: 128x128 Autistic 0.66, Non_Autistic 0.34, 3.6ms
# image 133/140 /content/ultralytics/autism/test/Autistic/133.jpg: 128x128 Non_Autistic 0.65, Autistic 0.35, 3.2ms
# image 134/140 /content/ultralytics/autism/test/Autistic/134.jpg: 128x128 Autistic 0.75, Non_Autistic 0.25, 3.2ms
# image 135/140 /content/ultralytics/autism/test/Autistic/135.jpg: 128x128 Autistic 0.81, Non_Autistic 0.19, 3.0ms
# image 136/140 /content/ultralytics/autism/test/Autistic/136.jpg: 128x128 Autistic 0.73, Non_Autistic 0.27, 3.0ms
# image 137/140 /content/ultralytics/autism/test/Autistic/137.jpg: 128x128 Autistic 0.75, Non_Autistic 0.25, 3.1ms
# image 138/140 /content/ultralytics/autism/test/Autistic/138.jpg: 128x128 Autistic 0.74, Non_Autistic 0.26, 3.1ms
# image 139/140 /content/ultralytics/autism/test/Autistic/139.jpg: 128x128 Autistic 0.70, Non_Autistic 0.30, 5.9ms
# image 140/140 /content/ultralytics/autism/test/Autistic/140.jpg: 128x128 Autistic 0.72, Non_Autistic 0.28, 4.9ms
# Speed: 0.1ms preprocess, 3.3ms inference, 0.0ms postprocess per image at shape (1, 3, 128, 128)
