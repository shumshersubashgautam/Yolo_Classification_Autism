# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.2/78.2 GB disk)

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/autism.zip /content/yolov5/

# %%
# Train YOLOv5s Classification on Imagenette160 for 3 epochs
# !python classify/train.py --model yolov5s-cls.pt --data /content/yolov5/autism --optimizer SGD --epochs 300 --img 224 --lr0  0.001 --cache
# Out:
# classify/train: model=yolov5s-cls.pt, data=/content/yolov5/autism, epochs=300, batch_size=64, imgsz=224, nosave=False, cache=ram, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=True, optimizer=SGD, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
# ...

# %% [markdown]
# SGD optimizer validation accuracy=89.30%

# %%
# !python classify/val.py --weights runs/train-cls/exp/weights/best.pt --data /content/yolov5/autism
# Out:
# classify/val: data=/content/yolov5/autism, weights=['runs/train-cls/exp/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# testing: 100% 3/3 [00:01<00:00,  2.12it/s]
#                    Class      Images    top1_acc    top5_acc
#                      all         280       0.893           1
#                 Autistic         140       0.871           1
#             Non_Autistic         140       0.914           1
# Speed: 0.1ms pre-process, 1.9ms inference, 0.1ms post-process per image at shape (1, 3, 224, 224)
# Results saved to runs/val-cls/exp

# %%
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/yolov5/autism/test/Autistic/
# Out:
# classify/predict: weights=['runs/train-cls/exp/weights/best.pt'], source=/content/yolov5/autism/test/Autistic/, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# image 1/140 /content/yolov5/autism/test/Autistic/001.jpg: 224x224 Autistic 0.85, Non_Autistic 0.15, 2.6ms
# image 2/140 /content/yolov5/autism/test/Autistic/002.jpg: 224x224 Autistic 0.79, Non_Autistic 0.21, 2.7ms
# image 3/140 /content/yolov5/autism/test/Autistic/003.jpg: 224x224 Autistic 0.80, Non_Autistic 0.20, 2.7ms
# image 4/140 /content/yolov5/autism/test/Autistic/004.jpg: 224x224 Autistic 0.97, Non_Autistic 0.03, 3.3ms
# ...

# %%
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/yolov5/autism/test/Non_Autistic/
# Out:
# classify/predict: weights=['runs/train-cls/exp/weights/best.pt'], source=/content/yolov5/autism/test/Non_Autistic/, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# image 1/140 /content/yolov5/autism/test/Non_Autistic/001.jpg: 224x224 Non_Autistic 0.94, Autistic 0.06, 3.3ms
# image 2/140 /content/yolov5/autism/test/Non_Autistic/002.jpg: 224x224 Non_Autistic 0.95, Autistic 0.05, 3.6ms
# image 3/140 /content/yolov5/autism/test/Non_Autistic/003.jpg: 224x224 Non_Autistic 0.99, Autistic 0.01, 4.0ms
# image 4/140 /content/yolov5/autism/test/Non_Autistic/004.jpg: 224x224 Non_Autistic 0.99, Autistic 0.01, 3.2ms
# ...

# %%
# Train YOLOv5s Classification on Imagenette160 for 3 epochs
# !python classify/train.py --model yolov5s-cls.pt --data /content/yolov5/autism --optimizer RMSProp --epochs 300 --img 224 --lr0  0.001 --cache
# Out:
# classify/train: model=yolov5s-cls.pt, data=/content/yolov5/autism, epochs=300, batch_size=64, imgsz=224, nosave=False, cache=ram, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=True, optimizer=RMSProp, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
# ...

# %% [markdown]
# RMSPROP Test Accuracy: 74.30%

# %%
# !python classify/val.py --weights runs/train-cls/exp2/weights/best.pt --data /content/yolov5/autism
# Out:
# classify/val: data=/content/yolov5/autism, weights=['runs/train-cls/exp2/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# testing: 100% 3/3 [00:01<00:00,  1.60it/s]
#                    Class      Images    top1_acc    top5_acc
#                      all         280       0.743           1
#                 Autistic         140       0.714           1
#             Non_Autistic         140       0.771           1
# Speed: 0.1ms pre-process, 2.9ms inference, 0.1ms post-process per image at shape (1, 3, 224, 224)
# Results saved to runs/val-cls/exp3

# %%
# !python classify/predict.py --weights runs/train-cls/exp2/weights/best.pt --source /content/yolov5/autism/test/Autistic/
# Out:
# classify/predict: weights=['runs/train-cls/exp2/weights/best.pt'], source=/content/yolov5/autism/test/Autistic/, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# image 1/140 /content/yolov5/autism/test/Autistic/001.jpg: 224x224 Non_Autistic 0.53, Autistic 0.47, 2.7ms
# image 2/140 /content/yolov5/autism/test/Autistic/002.jpg: 224x224 Autistic 0.61, Non_Autistic 0.39, 2.9ms
# image 3/140 /content/yolov5/autism/test/Autistic/003.jpg: 224x224 Non_Autistic 0.56, Autistic 0.44, 2.9ms
# image 4/140 /content/yolov5/autism/test/Autistic/004.jpg: 224x224 Non_Autistic 0.52, Autistic 0.48, 2.7ms
# ...

# %%
# !python classify/predict.py --weights runs/train-cls/exp2/weights/best.pt --source /content/yolov5/autism/test/Non_Autistic/
# Out:
# classify/predict: weights=['runs/train-cls/exp2/weights/best.pt'], source=/content/yolov5/autism/test/Non_Autistic/, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
# image 1/140 /content/yolov5/autism/test/Non_Autistic/001.jpg: 224x224 Non_Autistic 0.53, Autistic 0.47, 2.7ms
# image 2/140 /content/yolov5/autism/test/Non_Autistic/002.jpg: 224x224 Non_Autistic 0.61, Autistic 0.39, 2.8ms
# image 3/140 /content/yolov5/autism/test/Non_Autistic/003.jpg: 224x224 Non_Autistic 0.61, Autistic 0.39, 2.8ms
# image 4/140 /content/yolov5/autism/test/Non_Autistic/004.jpg: 224x224 Non_Autistic 0.61, Autistic 0.39, 2.8ms
# ...
